# %% [markdown]
# # Outlier Detection

# %% [markdown]
# * 下面這兩個 cell 會讓這個 nb file 沒辦法 export 成 .slides.html 但 live 很方便

# %%
# %%html
# <style>
#  .container.slides .celltoolbar, .container.slides .hide-in-slideshow {
#     display: None ! important;
# }
# </style>
# Out:
# <style>
#  .container.slides .celltoolbar, .container.slides .hide-in-slideshow {
#     display: None ! important;
# }
# </style>

# %%
def hide_code_in_slideshow():
    from IPython import display
    import binascii
    import os
    uid = binascii.hexlify(os.urandom(8)).decode()
    html = """<div id="%s"></div>
    <script type="text/javascript">
        $(function(){
            var p = $("#%s");
            if (p.length==0) return;

            while (!p.hasClass("cell")) {
                p=p.parent();

                if (p.prop("tagName") =="body") return;
            }
            var cell = p;
            cell.find(".input").addClass("hide-in-slideshow")
        });
    </script>""" % (uid, uid)
    display.display_html(html, raw=True)

# %% [markdown]
# ## Slide 1

# %%
hide_code_in_slideshow()

from pandas import DataFrame
import matplotlib.pyplot as plt

DataFrame([1, 2, 3, 4, 5]).plot()
plt.show()
# Out:
# <div id="63f50f02d05e41ed"></div>
#     <script type="text/javascript">
#         $(function(){
#             var p = $("#63f50f02d05e41ed");
#             if (p.length==0) return;
#
#             while (!p.hasClass("cell")) {
#                 p=p.parent();
#
#                 if (p.prop("tagName") =="body") return;
#             }
#             var cell = p;
#             cell.find(".input").addClass("hide-in-slideshow")
#         });
#     </script>

# %%
hide_code_in_slideshow()

import numpy as np
from bokeh.plotting import figure, show
from bokeh.io import output_notebook

N = 4000

x = np.random.random(size=N) * 100
y = np.random.random(size=N) * 100
radii = np.random.random(size=N) * 1.5
colors = ['#%02x%02x%02x' % (int(r), int(g), 150) for r, g in zip(np.floor(50+2*x), np.floor(30+2*y))]
output_notebook()

p = figure()
p.circle(x, y, radius=radii, fill_color=colors, fill_alpha=0.6, line_color=None)
show(p)
# Out:
# <div id="125da910821aa6e0"></div>
#     <script type="text/javascript">
#         $(function(){
#             var p = $("#125da910821aa6e0");
#             if (p.length==0) return;
#
#             while (!p.hasClass("cell")) {
#                 p=p.parent();
#
#                 if (p.prop("tagName") =="body") return;
#             }
#             var cell = p;
#             cell.find(".input").addClass("hide-in-slideshow")
#         });
#     </script>
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1001">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="4e44dba0-b0a2-4923-8e2a-0a093cb64057" data-root-id="1002"></div>
